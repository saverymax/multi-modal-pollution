# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
path = "../data/traffic/20210921-Tunnels2019-sept2021.xlsb"
traffic_df = pd.read_excel(path)

# %%
traffic_df.head()
# Out:
#    Typical Days                                 Date     From            To  \
# 0           NaN  01/01/2019 00:00 - 30/06/2019 23:59  43466.0  43466.041667
# 1           NaN  01/01/2019 00:00 - 30/06/2019 23:59  43466.0  43466.041667
# 2           NaN  01/01/2019 00:00 - 30/06/2019 23:59  43466.0  43466.041667
# 3           NaN  01/01/2019 00:00 - 30/06/2019 23:59  43466.0  43466.041667
# 4           NaN  01/01/2019 00:00 - 30/06/2019 23:59  43466.0  43466.041667
#
#                                      Detector  Volume  Occupancy  Speed  \
# 0  Trav. 15 sur le lien Tun Cinquant - Centre     327          3     62
# 1                              Tun Hal - Midi     541          1     86
# 2                                  Tun Bel IN     984          7     63
# 3               Tun Ste OUT - Cambre - Centre     137          2     44
# 4                               Tun Rog - Bas     877          9     58
#
#    Validity
# 0      0.92
# 1      0.99
# 2      0.97
# 3      0.88
# ...

# %%
traffic_df_reduced = traffic_df[['From', 'Detector', 'Volume', 'Occupancy', 'Speed']]

# %% [markdown]
# Some summary statistics

# %%
traffic_df_reduced.groupby('Detector')['Volume', 'Occupancy', 'Speed'].describe()
# Out:
# /home/timor/anaconda3/envs/sentinel_env/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#                                              Volume                           \
#                                               count         mean         std
# Detector
# Reyers - E40 - Centre                       23147.0   599.631097  408.258458
# Trav. 15 sur le lien Tun Cinquant - Centre  23151.0   719.532979  558.117726
# Tun ArL - Bas                               10185.0  1141.799018  688.368536
# Tun ArL - Midi                              11128.0  1323.651330  769.339428
# Tun Bai - Cambre                            19167.0   847.909271  629.413234
# Tun Bai - Centre                            19167.0   747.668754  562.009226
# Tun Bel Cinquant - Terv                     23157.0   549.891134  427.466896
# ...

# %% [markdown]
# plot time series for each tunnel, each variable

# %%
traffic_df_reduced['Date'] = pd.to_datetime(traffic_df_reduced['From'], format='%m%d%y%f')

# %%
traffic_df_reduced.head()
# Out:
#       From                                    Detector  Volume  Occupancy  \
# 0  43466.0  Trav. 15 sur le lien Tun Cinquant - Centre     327          3
# 1  43466.0                              Tun Hal - Midi     541          1
# 2  43466.0                                  Tun Bel IN     984          7
# 3  43466.0               Tun Ste OUT - Cambre - Centre     137          2
# 4  43466.0                               Tun Rog - Bas     877          9
#
#    Speed                    Date
# 0     62 2046-04-03 00:00:00.600
# 1     86 2046-04-03 00:00:00.600
# 2     63 2046-04-03 00:00:00.600
# 3     44 2046-04-03 00:00:00.600
# 4     58 2046-04-03 00:00:00.600

# %%
traffic_df_reduced['Date']
# Out:
# 0        2046-04-03 00:00:00.600
# 1        2046-04-03 00:00:00.600
# 2        2046-04-03 00:00:00.600
# 3        2046-04-03 00:00:00.600
# 4        2046-04-03 00:00:00.600
#                    ...
# 686569                       NaT
# 686570                       NaT
# 686571                       NaT
# 686572                       NaT
# 686573                       NaT
# Name: Date, Length: 686574, dtype: datetime64[ns]
